# %% [markdown]
# ### Exercice 1
# Exercice 1 -Utilisation de NumPy
# Les nombres aléatoires
# 1. Générer un numpy array de 10 valeurs aléatoires.
# 2. Générer un numpy array de 100 valeurs entières entre 0 et 100.
# 3. Générer un numpy array de taille 25 avec des nombres tirés aléatoirement suivant une distribution normale centrée réduite.
# 4. Générer un numpy array de taille 25 avec des nombres tirés aléatoirement suivant une loi uniforme.
# 5. Générer une matrice aléatoire de dimension 2 et de taille 10×10.
# 6. Modifier votre programme pour que les nombres aléatoires générés soient toujours les mêmes à chaque exécution.

# %%
import numpy as np
np.random.seed(0)

random10 = np.random.random(10)
print("Numpy array de 10 valeurs aléatoires : ")
print(str(random10)+"\n")

random100 = np.random.randint(0,101,100)
print("Numpy array de 100 valeurs entières aléatoires : ")
print(str(random100)+"\n")

random_norm = np.random.standard_normal(25)
print("Numpy array de 25 valeurs tirés suivant une distribution normale centrée réduite : ")
print(str(random_norm)+"\n")

random_unif = np.random.uniform(0,1,25)
print("Numpy array de 25 valeurs tirés suivant une distribution uniforme dans [0,1] : ")
print(str(random_unif)+"\n")

matrandom = np.random.random((10,10))
print("Matrice aléatoire 10x10 : ")
print(str(matrandom)+"\n")
# Out:
# Numpy array de 10 valeurs aléatoires :
# [0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411
#  0.43758721 0.891773   0.96366276 0.38344152]
#
# Numpy array de 100 valeurs entières aléatoires :
# [ 39  87  46  88  81  37  25  77  72   9  20  80  69  79  47  64  82  99
#   88  49  29  19  19  14  39  32  65   9  57  32  31  74  23  35  75  55
#   28  34   0   0  36  53   5  38  17  79   4  42  58  31   1  65  41  57
#   35  11  46  82  91   0  14  99  53  12  42  84  75  68   6  68  47   3
#   76 100  52  78  15  20  99  58  23  79  13  85  48  49  69  41  35  64
#   95  69  94   0  50  36  34  48  93   3]
#
# Numpy array de 25 valeurs tirés suivant une distribution normale centrée réduite :
# [ 0.4253934  -0.02797118  1.47598983  0.6467801  -0.36433431 -0.67877739
#  -0.35362786 -0.74074747 -0.67502183 -0.13278426  0.61980106  1.79116846
#   0.17100044 -1.72567135  0.16065854 -0.85898532 -0.20642094  0.48842647
# ...

# %% [markdown]
# Les entrées/sorties
# 1. Sauvegarder une matrice aléatoire de taille 10 × 10 dans un fichier matrice1.csv avec ’ ;’ comme séparateur.
# 2. Charger le fichier matrice1.csv.

# %%
matrice1 = np.random.random((10,10))
print("Matrice avant écriture : ")
print(str(matrice1)+"\n")
np.savetxt("matrice1.csv",matrice1,delimiter=";")
matrice2 = np.loadtxt("matrice1.csv",delimiter=";")
print("Matrice après lecture : ")
print(str(matrice2)+"\n")
# Out:
# Matrice avant écriture :
# [[0.94737059 0.73085581 0.25394164 0.21331198 0.51820071 0.02566272
#   0.20747008 0.42468547 0.37416998 0.46357542]
#  [0.27762871 0.58678435 0.86385561 0.11753186 0.51737911 0.13206811
#   0.71685968 0.3960597  0.56542131 0.18327984]
#  [0.14484776 0.48805628 0.35561274 0.94043195 0.76532525 0.74866362
#   0.90371974 0.08342244 0.55219247 0.58447607]
#  [0.96193638 0.29214753 0.24082878 0.10029394 0.01642963 0.92952932
#   0.66991655 0.78515291 0.28173011 0.58641017]
#  [0.06395527 0.4856276  0.97749514 0.87650525 0.33815895 0.96157015
#   0.23170163 0.94931882 0.9413777  0.79920259]
#  [0.63044794 0.87428797 0.29302028 0.84894356 0.61787669 0.01323686
#   0.34723352 0.14814086 0.98182939 0.47837031]
#  [0.49739137 0.63947252 0.36858461 0.13690027 0.82211773 0.18984791
#   0.51131898 0.22431703 0.09784448 0.86219152]
#  [0.97291949 0.96083466 0.9065555  0.77404733 0.33314515 0.08110139
#   0.40724117 0.23223414 0.13248763 0.05342718]
# ...

# %% [markdown]
# ### Exercice 2 - Utilisation de pandas
# 1. Construire un dataframe de quatre colonnes nommées A, B, C et D et trois lignes numérotées i1, i2 et i3 remplies de 1.
# 2. Construire un dataframe de quatre colonnes nommées p1, p2, p3 et p4 et 100 lignes numérotées de i1 à i100 remplies du
# chiffre 1 uniquement pour l’instant.

# %%
import pandas as pd

df1 = pd.DataFrame(data = np.ones((3,4)),columns = ["A","B","C","D"],index = ["i1","i2","i3"])
print("Data Frame n°1 :")
print(df1)

data = np.ones((100,4))
col = ["p1","p2","p3","p4"]
idx = ["i"+str(i) for i in range(1,101)]
df2 = pd.DataFrame(data=data,columns=col,index=idx)
print("Data Frame 2 :")
print(df2)
# Out:
# Data Frame n°1 :
#       A    B    C    D
# i1  1.0  1.0  1.0  1.0
# i2  1.0  1.0  1.0  1.0
# i3  1.0  1.0  1.0  1.0
# Data Frame 2 :
#        p1   p2   p3   p4
# i1    1.0  1.0  1.0  1.0
# i2    1.0  1.0  1.0  1.0
# i3    1.0  1.0  1.0  1.0
# i4    1.0  1.0  1.0  1.0
# i5    1.0  1.0  1.0  1.0
# ...   ...  ...  ...  ...
# i96   1.0  1.0  1.0  1.0
# i97   1.0  1.0  1.0  1.0
# i98   1.0  1.0  1.0  1.0
# i99   1.0  1.0  1.0  1.0
# i100  1.0  1.0  1.0  1.0
#
# [100 rows x 4 columns]

# %% [markdown]
# 3. Modifier le dataframe pour que la colonne p1 contiennent tous les nombres de 1 à 100 en ligne à la puissance 1, jusqu’à p4 contenant tous les nombres de 1 à 100 à la puissance 4 en ligne.

# %%
df2["p2"]=np.arange(1,101)**2
df2["p3"]=np.arange(1,101)**3
df2["p4"]=np.arange(1,101)**4
print("Data Frame 2 après modif : ")
print(df2)
# Out:
# Data Frame 2 après modif :
#        p1     p2       p3         p4
# i1    1.0      1        1          1
# i2    1.0      4        8         16
# i3    1.0      9       27         81
# i4    1.0     16       64        256
# i5    1.0     25      125        625
# ...   ...    ...      ...        ...
# i96   1.0   9216   884736   84934656
# i97   1.0   9409   912673   88529281
# i98   1.0   9604   941192   92236816
# i99   1.0   9801   970299   96059601
# i100  1.0  10000  1000000  100000000
#
# [100 rows x 4 columns]

# %% [markdown]
# 4. Afficher la forme du dataframe.
# 5. Afficher les 10 premiers éléments du dataframe.
# 6. Afficher les 10 derniers éléments du dataframe.
# 7. Afficher le noms des colonnes.
# 8. Afficher le type de données des colonnes.
# 9. Afficher les statistiques pour le dataframe.
# 10. Afficher les données de la colonne p4 uniquement.
# 11. Afficher les données des colonnes p1 et p4 uniquement.
# 12. Afficher la moyenne des lignes et la moyenne des colonnes de ce dataframe.

# %%
print("La forme de df2 est :" + str(df2.shape))
print("Les 10 premiers éléments de df2 sont : \n"+str(df2.head(10))+"\n")
print("Les 10 derniers éléments de df2 sont : \n"+str(df2.tail(10))+"\n")
# L'appel à la méthode tolist() n'est utile que pour avoir un meilleur affichage
print("Les colonnes sont : \n" +str(df2.columns.tolist())+"\n")
print("Le type de données des colonnes : \n"+str(df2.dtypes.tolist())+"\n")
print("Les statistiques du dataframe : \n"+str(df2.describe(include="all"))+"\n")
print("Les données de p4 sont : \n"+str(df2["p4"])+"\n")
print("Les données de p1 et p4 sont : \n"+str(df2[['p1', 'p4']])+"\n")
print("La moyenne des lignes est : \n"+str(df2.mean(axis=1))+"\n")
print("La moyenne des colonnes est : \n"+str(df2.mean(axis=0))+"\n")
# Out:
# La forme de df2 est :(100, 4)
# Les 10 premiers éléments de df2 sont :
#       p1   p2    p3     p4
# i1   1.0    1     1      1
# i2   1.0    4     8     16
# i3   1.0    9    27     81
# i4   1.0   16    64    256
# i5   1.0   25   125    625
# i6   1.0   36   216   1296
# i7   1.0   49   343   2401
# i8   1.0   64   512   4096
# i9   1.0   81   729   6561
# i10  1.0  100  1000  10000
#
# Les 10 derniers éléments de df2 sont :
#        p1     p2       p3         p4
# i91   1.0   8281   753571   68574961
# i92   1.0   8464   778688   71639296
# i93   1.0   8649   804357   74805201
# i94   1.0   8836   830584   78074896
# i95   1.0   9025   857375   81450625
# i96   1.0   9216   884736   84934656
# i97   1.0   9409   912673   88529281
# i98   1.0   9604   941192   92236816
# i99   1.0   9801   970299   96059601
# i100  1.0  10000  1000000  100000000
#
# Les colonnes sont :
# ['p1', 'p2', 'p3', 'p4']
#
# Le type de données des colonnes :
# ...

# %% [markdown]
# ### Exercice 3
# 1. Charger les fichiers redwinePD.csv et whitewinePD.csv
# 2. Afficher les 5 alcools avec le plus grand taux d’alcool (avec le plus grand taux en premier puis dans l’ordre décroissant)
# 3. Afficher les alcools dont la qualité est supérieure à 7

# %%
import pandas as pd

redwine = pd.read_csv("redwine.csv", sep = ";", index_col = 0)
whitewine = pd.read_csv("whitewine.csv",sep = ";", index_col = 0)

wines = pd.concat([redwine,whitewine],axis=0)

print("Les 5 alcools avec le plus grand taux d'alcool sont : ")
print(wines.sort_values(by="alcohol").head(5))

print("Les alcools avec une qualité supérieure à 7 sont")
print(wines.loc[wines["quality"]>7])
# Out:
# Les 5 alcools avec le plus grand taux d'alcool sont :
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 4.2                       0.215         0.23            5.10      0.041
# 4.5                       0.190         0.21            0.95      0.033
# 6.2                       0.310         0.23            3.30      0.052
# 6.2                       0.310         0.23            3.30      0.052
# 14.3                      0.310         0.74            1.80      0.075
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 4.2                           64.0                 157.0  0.99688  3.42
# 4.5                           89.0                 159.0  0.99332  3.34
# 6.2                           34.0                 113.0  0.99429  3.16
# 6.2                           34.0                 113.0  0.99429  3.16
# 14.3                           6.0                  15.0  1.00080  2.86
#
# ...

# %% [markdown]
# 4. Calculer le ratio d’alcools dont la qualité est supérieure à 7 pour le vin rouge et le vin blanc
# 5. Afficher les vins dont la qualité est supérieure à 7 et la quantité d’alcool inférieure à 10 pour le vin rouge et 9 pour le vin
# blanc en ne conservant que les colonnes quality et alcohol

# %%
print("Le ratio d'alcools dont la qualité est supérieure à 7 pour le vin rouge est :")
df_qualred = redwine.loc[redwine["quality"]>7]
print(df_qualred.shape[0]/redwine.shape[0])

df_qualwhite = whitewine.loc[whitewine["quality"]>7]
print("Le ratio d'alcools dont la qualité est supérieure à 7 pour le vin blanc est :")
print(df_qualwhite.shape[0]/whitewine.shape[0])

df_q5 = df_qualred.loc[df_qualred["alcohol"]<10]
df_q5 = pd.concat([df_q5,df_qualwhite.loc[df_qualwhite["alcohol"]<9]],axis=0)
df_q5 = df_q5[["quality","alcohol"]]
print("Réponse question 5 :")
print(df_q5)
# Out:
# Le ratio d'alcools dont la qualité est supérieure à 7 pour le vin rouge est :
# 0.01125703564727955
# Le ratio d'alcools dont la qualité est supérieure à 7 pour le vin blanc est :
# 0.03674969375255206
# Réponse question 5 :
#                quality  alcohol
# fixed acidity
# 12.6                 8      9.8
# 8.1                  8      8.8
# 8.1                  8      8.8
# 7.8                  8      8.5
# 6.9                  8      8.8
# 7.6                  8      8.9
# 7.6                  8      8.9
# 7.6                  8      8.9
# 7.6                  8      8.9
# 7.6                  8      8.9
# 7.6                  8      8.9
# 7.3                  8      8.8
# 7.3                  8      8.8
# 7.3                  8      8.8
# 7.3                  8      8.8
# 7.3                  8      8.8
# 7.3                  8      8.8
# 7.3                  8      8.8
# 7.3                  8      8.8

# %% [markdown]
# 6. Afficher la proportion de vin en fonction de leur qualité dans un camembert (pie)

# %%
import matplotlib.pyplot as plt

wines["quality"].value_counts().plot.pie()
plt.show()

# %% [markdown]
# 7. Afficher un nuage de points représentant la quantité d’alcool en fonction de la qualité
# 8. Ajouter une nuance de couleur pour le taux de "volatile acidity"

# %%
wines.plot.scatter(x="alcohol",y="quality",c="volatile acidity")
plt.show()

# %% [markdown]
# 9. Afficher sous la forme d’une boxplot (boîte à moustache) les différents quartiles de la répartition d’alcool en fonction de
# la qualité

# %%
wines.boxplot(column="alcohol",by="quality")
plt.show()

# %% [markdown]
# 10. Afficher sous la forme d’un histogramme la répartition des vins en fonction de leur taux d’alcool11. Afficher plusieurs histogrammes montrant la répartition des vins en fonction de leur taux d’alcool et de leur qualité

# %%
wines.hist("alcohol")
plt.plot()
# Out:
# []

# %% [markdown]
# 11. Afficher plusieurs histogrammes montrant la répartition des vins en fonction de leur taux d’alcool et de leur qualité

# %%
wines.hist(column="alcohol",by="quality")
plt.show()

# %% [markdown]
# 12. Afficher la quantité de vins pour un intervalle donné d’alcool et une qualité. On utilisera pour cela un tableau croisé
# après avoir défini un groupe (avec la fonction cut de pandas) contenant des intervalles pour les degrés d’alcool. On fera
# l’affichage avec 10 intervalles.

# %%
wines["groupe_deg"] = pd.cut(wines['alcohol'], bins=10)
print(pd.crosstab(wines["quality"],wines["groupe_deg"]))
# Out:
# groupe_deg  (7.993, 8.69]  (8.69, 9.38]  (9.38, 10.07]  (10.07, 10.76]  \
# quality
# 3                       3             3              8               6
# 4                       5            42             62              47
# 5                      21           591            869             355
# 6                       7           397            648             591
# 7                       3            83             69             141
# 8                       1            17              6              15
# 9                       0             0              0               1
#
# groupe_deg  (10.76, 11.45]  (11.45, 12.14]  (12.14, 12.83]  (12.83, 13.52]  \
# quality
# 3                        6               2               2               0
# 4                       37              15               5               3
# 5                      211              61              18              10
# 6                      558             295             271              56
# ...

# %% [markdown]
# ### Exercice 4
# 1. À partir de deux tableaux [1,4,8,9] et [12,25,34,78] afficher un nuage de points.
# 2. À partir d’un tableau numpy aléatoire de 1000 entiers afficher un nuage de points.
# 3. À partir de deux tableaux [1,4,8,9] et [12,25,34,78] tracer une courbe.
# 4. À partir d’un tableau numpy aléatoire de 100 nombres suivant une distribution normale tracer une courbe.

# %%
import matplotlib.pyplot as plt
tab1 = [1,4,8,9]
tab2 = [12,25,34,78]
plt.scatter(tab1,tab2,color='red')
plt.plot([1,4,8,9],[12,25,34,78],color='blue')
plt.show()

# %% [markdown]
# 5. Tracer trois courbes avec x allant de 0 à 2 avec 100 valeurs, représentant une fonction linéaire, carrée et cubique sur la
# même figure.
# 6. Ajouter une légende à ces trois courbes signifiant linéaire, quadratique, cubique.
# 7. Ajouter un titre "Comparaison des fonctions linéaire, quadratique et cubique".
# 8. Changer les labels par abscisse et ordonnée.

# %%
x = np.arange(0,2,0.02)
y2 = x ** 2
y3 = x ** 3
plt.plot(x,x,color='blue',label='Linéaires')
plt.plot(x,y2,color='orange',label='Quadratique')
plt.plot(x,y3,color='green',label='Cubique')
plt.grid(True)
plt.legend()
plt.title("Comparaison des fonctions linéaire, quadratique et cubique")
plt.ylabel("Ordonée")
plt.xlabel("Abscisse")
plt.show()

# %% [markdown]
# 9. Retracer les trois courbes mais dans 3 figures les unes à côté des autres en attribuant les couleurs bleue, orange et verte.
# 10. Changer la taille de la figure par (20,7).

# %%
plt.subplot(131)
plt.plot(x,x,color='blue',label='Linéaires')
plt.grid(True)
plt.legend()
plt.subplot(132)
plt.plot(x,y2,color='orange',label='Quadratique')
plt.grid(True)
plt.legend()
plt.subplot(133)
plt.plot(x,y3,color='green',label='Cubique')
plt.grid(True)
plt.legend()

plt.title("Comparaison des fonctions linéaire, quadratique et cubique")
plt.ylabel("Ordonée")
plt.xlabel("Abscisse")
plt.show()

# %% [markdown]
# 11. À partir d’un tableau numpy aléatoire uniforme de 100 éléments allant de 0 à 10 tracer un histogramme constitué de 10
# bandes verticales.

# %%
tab = np.random.uniform(0,1,100)
plt.hist(tab)
plt.show()

# %% [markdown]
# ### Exerice 6
# 1. Choisir une graine pour la génération de nombres aléatoires.
# 2. Créer un numpy array avec une distribution normale de 500 nombres aléatoires.
# 3. Affecter à cette distribution un coefficient de $\sigma$ + $\mu$ avec par défaut $\sigma$ = 15 et $\mu$ = 100  ($f(x) = x \cdot \sigma + \mu$)
# 4. Générer l’histogramme correspondant avec 50 bandes verticales.
# 5. Changer l’axe y par "Probabilité de densité"
# 6. Changer l’axe x par "Quotient intellectuel"
# 7. Ajouter un quadrillage
# 8.  Calculer la fonction représentant une loi normale à partir de $\sigma$ et $\mu$. Rappel de la fonction :
#     $$ \Large y =  \frac{1}{\sigma \sqrt{2\pi}} e^{{-\frac{1}{2} (\frac{x-\mu}{\sigma}})^2} $$
#     Ici x sera remplacé par bins qui correspond aux valeurs des abscisses de chaque bande verticale de l’histogramme
# 9. Tracer la fonction y en pointillés.
# 10. Changer le titre par "Histogramme de la répartition du QI : $\mu$ = 100, $\sigma$ = 15"

# %%
np.random.seed(0)

tab = np.random.normal(0,1,500)

sigma = 15
mu = 100
tab = tab*sigma + mu

counts, bins,_ = plt.hist(tab,50,density=True)

plt.ylabel("Probabilité de densité")
plt.xlabel('Quotient intellectuel')
plt.grid(True)

y = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((bins - mu) / sigma) ** 2)

plt.plot(bins, y, ':', color='red', label='PDF')
plt.title(r"Histogramme de la répartition du qi : $\mu$ = 100, $\sigma$ = 15 ")

plt.show()
